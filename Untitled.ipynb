# %%
import pandas as pd

# %%
# !tree
# Out:
# .
# ├── Dockerfile
# ├── LICENCE
# ├── MANIFEST.in
# ├── README.md
# ├── SECURITY.md
# ├── Untitled.ipynb
# ├── bestridge.joblib
# ├── crowdin.yml
# ├── data
# │   ├── brand_prefix.json
# │   ├── clf_category_blacklist.txt
# │   ├── ocr
# │   │   ├── brand.txt
# │   │   ├── brand_from_taxonomy.txt
# │   │   ├── brand_logo_annotation.txt
# │   │   ├── brand_taxonomy_blacklist.txt
# │   │   ├── cities_laposte_hexasmal.json.gz
# │   │   ├── fishing_flashtext.txt
# │   │   ├── image_flag_beauty.txt
# │   │   ├── image_flag_miscellaneous.txt
# │   │   ├── label_flashtext.txt
# │   │   ├── label_logo_annotation.txt
# │   │   ├── label_whitelist.txt
# │   │   ├── packaging.txt
# │   │   ├── store_notify.txt
# │   │   ├── store_regex.txt
# │   │   └── trace_allergen.txt
# │   ├── spellcheck
# │   │   └── patterns_fr.txt
# │   └── taxonomies
# │       ├── brands.full.json
# │       ├── categories.full.json
# │       ├── fr_tokens_lower.gz
# │       ├── ingredients.full.json
# ...

# %%
df = pd.read_json('data.json', lines=True)

# %%
with open('data.json') as f:
  df = json.load(f)

df
# Out:
# '{"expiration_date": {"insights": [{"type": "expiration_date", "data": {"raw": "10/04/18", "type": "full_digits_short", "notify": false}, "value_tag": null, "value": "2018-04-10", "automatic_processing": null, "predictor": null}, {"type": "expiration_date", "data": {"raw": "30/03/18", "type": "full_digits_short", "notify": false}, "value_tag": null, "value": "2018-03-30", "automatic_processing": null, "predictor": null}], "barcode": "3199660476748", "type": "expiration_date", "source_image": "/319/966/047/6748/1.jpg"}, "label": {"insights": [{"type": "label", "data": {"confidence": 0.88425}, "value_tag": "en:label-rouge", "value": null, "automatic_processing": false, "predictor": "google-cloud-vision"}], "barcode": "3199660476748", "type": "label", "source_image": "/319/966/047/6748/1.jpg"}, "category": {"insights": [{"type": "category", "data": {"proba": "meat", "max_confidence": 0.0992}, "value_tag": null, "value": null, "automatic_processing": null, "predictor": "ridge_model-ml"}]
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-bca44161b613> in <module>
# ----> 1 for key in df.keys():
#       2     print(key)
#
# AttributeError: 'str' object has no attribute 'keys'

# %%
data = pd.read_csv('ocr_labeled_1K.csv')

# %%
pd.set_option('display.max_colwidth', None)

# %%
data[470:480]
# Out:
#            barcode                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    
# ...

# %%
relogios_presentes = df[df['product_category_name'] == 'relogios_presentes']
# Out:
# [0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  995    False
#  996    False
#  997    False
#  998    False
#  999    False
#  Name: clean_text, Length: 1000, dtype: bool]
