# %%
from collections import Counter

import categories
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, precision_score
from sklearn.externals import joblib
from more_itertools import flatten

from ml import import_data, create_classifier

# %%
df = import_data("data/en.openfoodfacts.org.products.csv")
fr_df = df[df['countries_tags'] == 'en:france']
filt_df = fr_df[pd.notnull(fr_df['categories_tags'])]
# Out:
# /usr/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2903: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):

# %%
categories_counter = Counter(flatten(c for c in filt_df['categories_tags']))
print("Number of categories: {}".format(len(categories_counter)))
# Out:
# Number of categories: 12390

# %%
selected_categories = [
    "en:beverages",
    "en:sugary-snacks",
    "en:meals",
    "en:dairies",
    "en:meats",
    "en:desserts",
    "en:frozen-foods",
    "en:breakfasts",
    "en:cheeses",
    "en:biscuits",
    "en:groceries",
    "en:fats",
    "en:chocolates",
    "en:sauces",
]

selected_categories_set = set(selected_categories)

# %%
criterion = filt_df['categories_tags'].map(lambda x: bool(set(x).intersection(selected_categories_set)))
cat_df = filt_df[criterion]
cat_df['categories_tags_int'] = cat_df.categories_tags.apply(lambda categories: [selected_categories.index(x) for x in categories if x in selected_categories])
cat_df['categories_tags_array'] = cat_df.categories_tags.apply(lambda categories: [1 if x in categories else 0 for x in selected_categories])
print(f"{len(fr_df)} elements in original dataframe, {len(cat_df)} after category filter")
# Out:
# /usr/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# 405973 elements in original dataframe, 92160 after category filter
# /usr/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
TRAIN = True

df_train, df_test = train_test_split(cat_df, random_state=42)
y_train = np.array(list(df_train.categories_tags_array.values))
y_test = np.array(list(df_test.categories_tags_array.values))

if TRAIN:
    classifier = create_classifier(custom_tokenizer=True)
    classifier.fit(df_train, y_train)
else:
    classifier = joblib.load('clf-model-wide.joblib')

y_pred = classifier.predict(df_test)
print(classification_report(y_test, y_pred, target_names=selected_categories))
# Out:
# /home/raphael/.local/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
#                   precision    recall  f1-score   support
#
#     en:beverages       0.96      0.89      0.92      5315
# en:sugary-snacks       0.94      0.89      0.91      4552
#         en:meals       0.92      0.84      0.88      2990
#       en:dairies       0.96      0.84      0.90      3171
#         en:meats       0.96      0.87      0.91      1947
#      en:desserts       0.89      0.63      0.74      1707
#  en:frozen-foods       0.86      0.54      0.66      1569
#    en:breakfasts       0.95      0.80      0.87      1820
#       en:cheeses       0.97      0.86      0.91      1343
#      en:biscuits       0.91      0.75      0.82       997
#     en:groceries       0.95      0.77      0.85      1505
#          en:fats       0.98      0.78      0.87       963
#    en:chocolates       0.91      0.71      0.80      1110
#        en:sauces       0.94      0.76      0.84       948
#
#        micro avg       0.94      0.81      0.87     29937
#        macro avg       0.93      0.78      0.85     29937
#     weighted avg       0.94      0.81      0.87     29937
#      samples avg       0.85      0.83      0.83     29937
# /home/raphael/.local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels.
#   'precision', 'predicted', average, warn_for)

# %%
# Out:
# /home/raphael/.local/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
#                   precision    recall  f1-score   support
#
#     en:beverages       0.96      0.89      0.92      5315
# en:sugary-snacks       0.95      0.88      0.91      4552
#         en:meals       0.92      0.83      0.87      2990
#       en:dairies       0.96      0.84      0.90      3171
#         en:meats       0.96      0.87      0.91      1947
#      en:desserts       0.89      0.63      0.74      1707
#  en:frozen-foods       0.86      0.53      0.66      1569
#    en:breakfasts       0.96      0.80      0.87      1820
#       en:cheeses       0.97      0.86      0.91      1343
#      en:biscuits       0.91      0.74      0.82       997
#     en:groceries       0.95      0.77      0.85      1505
#          en:fats       0.98      0.78      0.87       963
#    en:chocolates       0.91      0.71      0.79      1110
#        en:sauces       0.95      0.76      0.84       948
#
#        micro avg       0.94      0.81      0.87     29937
#        macro avg       0.94      0.78      0.85     29937
#     weighted avg       0.94      0.81      0.87     29937
#      samples avg       0.84      0.83      0.83     29937
# /home/raphael/.local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels.
#   'precision', 'predicted', average, warn_for)

# %%
y = np.array(list(cat_df.categories_tags_array.values))
X = cat_df.ingredients_text.values

X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
classifier = Pipeline([
    ('vectorizer', CountVectorizer(min_df=5, preprocessor=preprocess)),
    ('tfidf', TfidfTransformer()),
    ('clf', OneVsRestClassifier(LogisticRegression()))])

classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)
print(classification_report(y_test, y_pred, target_names=selected_categories))
# Out:
# /home/raphael/.local/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
#                   precision    recall  f1-score   support
#
#     en:beverages       0.94      0.69      0.80      5420
# en:sugary-snacks       0.93      0.75      0.83      4463
#         en:meals       0.88      0.73      0.80      2967
#       en:dairies       0.95      0.70      0.80      3191
#         en:meats       0.94      0.77      0.85      1958
#      en:desserts       0.84      0.47      0.60      1717
#  en:frozen-foods       0.82      0.40      0.54      1514
#    en:breakfasts       0.93      0.57      0.70      1825
#       en:cheeses       0.95      0.72      0.82      1355
#      en:biscuits       0.84      0.61      0.70      1037
#     en:groceries       0.87      0.56      0.68      1491
#          en:fats       0.97      0.58      0.72       993
#    en:chocolates       0.87      0.56      0.68      1073
#        en:sauces       0.86      0.53      0.66       937
#
#        micro avg       0.91      0.65      0.76     29941
#        macro avg       0.90      0.62      0.73     29941
#     weighted avg       0.91      0.65      0.76     29941
#      samples avg       0.68      0.66      0.66     29941
# /home/raphael/.local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels.
#   'precision', 'predicted', average, warn_for)

# %%
i = 0
print(X_test[i])
print(preprocess(X_test[i]))
# Out:
# Eau de source 84,6%, sucre, jus de pomme à base de concentré 6,5%, jus de cassis à base de concentré 3,5%, acidifiant (acide citrique), arômes
# eau de source sucre jus de pomme a base de concentre jus de cassis a base de concentre acidifiant acide citrique aromes

# %%
def predict(text):
    pred = classifier.predict([text])[0]
    return [selected_categories[i] for i in range(len(pred)) if pred[i]]

# %%
i = 10
print(X_test[i])
print(predict(X_test[i]))
print([selected_categories[k] for k in range(len(y_test[i])) if y_test[i][k]])
# Out:
# Jambon de porc VPF, sel, dextrose, conservateurs : erythorbate et nitrite de sodium, arômes.
# ['en:meats']
# ['en:meats']

# %%
print(predict("eau, sucres"))
# Out:
# ['en:beverages']

# %%
df_train, df_test = train_test_split(cat_df)
y_train = np.array(list(df_train.categories_tags_array.values))
y_test = np.array(list(df_test.categories_tags_array.values))

column_trans = ColumnTransformer([
    ('ingredients_vectorizer', CountVectorizer(min_df=5, preprocessor=preprocess), 'ingredients_text'),
    ('product_name_vectorizer', CountVectorizer(min_df=5, preprocessor=preprocess), 'product_name'),
])

column_trans.fit(df_train)

classifier = Pipeline([
    ('column_transformer', column_trans),
    ('tfidf', TfidfTransformer()),
    ('clf', OneVsRestClassifier(LogisticRegression()))])

classifier.fit(df_train, y_train)
y_pred = classifier.predict(df_test)
print(classification_report(y_test, y_pred, target_names=selected_categories))
# Out:
# /home/raphael/.local/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
#                   precision    recall  f1-score   support
#
#     en:beverages       0.96      0.90      0.93      5313
# en:sugary-snacks       0.95      0.87      0.91      4583
#         en:meals       0.92      0.84      0.88      3047
#       en:dairies       0.96      0.84      0.90      3106
#         en:meats       0.96      0.87      0.91      1906
#      en:desserts       0.92      0.61      0.73      1776
#  en:frozen-foods       0.87      0.52      0.65      1534
#    en:breakfasts       0.94      0.81      0.87      1837
#       en:cheeses       0.97      0.87      0.92      1361
#      en:biscuits       0.91      0.72      0.80      1033
#     en:groceries       0.95      0.76      0.84      1581
#          en:fats       0.98      0.75      0.85       938
#    en:chocolates       0.88      0.73      0.80      1019
#        en:sauces       0.96      0.78      0.86      1015
#
#        micro avg       0.94      0.81      0.87     30049
#        macro avg       0.94      0.78      0.85     30049
#     weighted avg       0.94      0.81      0.87     30049
#      samples avg       0.84      0.82      0.83     30049
# /home/raphael/.local/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels.
#   'precision', 'predicted', average, warn_for)

# %%
clf = classifier.steps[2][1]
beverage_coeff = clf.coef_[0, :]

# %%
column_trans
# Out:
# ColumnTransformer(n_jobs=None, remainder='drop', sparse_threshold=0.3,
#          transformer_weights=None,
#          transformers=[('ingredients_vectorizer', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=5,
#         ngram_range=(1, 1),
#         preprocessor=<fu...=None,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, vocabulary=None), 'product_name')])

# %%
def analyze_top_features(features, scores, top=10, negative=False):
    sorted_scores_features = sorted(zip(features, scores), key=lambda x: x[1], reverse=not negative)
    return sorted_scores_features[:top]

# %%
len(column_trans.get_feature_names())
# Out:
# 10711

# %%
for i in range(len(selected_categories)):
    category = selected_categories[i]
    print(category)
    coef = clf.coef_[i, :]
    top_features = analyze_top_features(column_trans.get_feature_names(), coef, 20)
    for feature, score in top_features:
        print("{}: {}".format(feature, score))
    print("")
# Out:
# en:beverages
# product_name_vectorizer__jus: 10.775450263052933
# ingredients_vectorizer__eau: 7.428921536441256
# product_name_vectorizer__boire: 7.04305341051363
# ingredients_vectorizer__jus: 6.979689280532793
# product_name_vectorizer__the: 6.829278696948448
# product_name_vectorizer__nectar: 6.678503539160729
# product_name_vectorizer__boisson: 6.391223996845006
# ingredients_vectorizer__gazeifiee: 5.754354999331071
# product_name_vectorizer__infusion: 5.6564581111475265
# product_name_vectorizer__eau: 5.260356371111634
# ingredients_vectorizer__the: 5.118364271741177
# product_name_vectorizer__sirop: 5.087890451664498
# ingredients_vectorizer__cafe: 4.78472644641649
# ingredients_vectorizer__base: 4.497150313101522
# product_name_vectorizer__limonade: 4.311640329192033
# ingredients_vectorizer__houblon: 4.303870276415494
# product_name_vectorizer__tea: 4.267282271220333
# ingredients_vectorizer__sulfites: 4.1789964325046665
# product_name_vectorizer__cidre: 3.942779854597489
# product_name_vectorizer__smoothie: 3.771112364271865
#
# en:sugary-snacks
# product_name_vectorizer__chocolat: 6.568985934434257
# ingredients_vectorizer__beurre: 6.436330446850491
# product_name_vectorizer__bonbons: 5.609206703964365
# product_name_vectorizer__barres: 5.442738438156653
# product_name_vectorizer__noir: 5.320035414068062
# ingredients_vectorizer__lever: 5.281245926204443
# product_name_vectorizer__biscuits: 5.2772225098058385
# product_name_vectorizer__sables: 4.982679142341167
# product_name_vectorizer__gateau: 4.891408029138947
# ingredients_vectorizer__glycerol: 4.859748195657996
# ingredients_vectorizer__sorbitol: 4.788101470469284
# product_name_vectorizer__madeleines: 4.784531953916313
# ingredients_vectorizer__gelatine: 4.748010077423415
# product_name_vectorizer__meringues: 4.712338463494155
# product_name_vectorizer__gaufres: 4.680166567687254
# ingredients_vectorizer__ufs: 4.633425442467746
# ingredients_vectorizer__farine: 4.592808566211592
# product_name_vectorizer__cake: 4.365710939713246
# product_name_vectorizer__panettone: 4.248329245332218
# product_name_vectorizer__brioche: 4.198796354911176
#
# en:meals
# product_name_vectorizer__soupe: 6.636197893199584
# ingredients_vectorizer__dur: 6.098387770239969
# ingredients_vectorizer__sauce: 5.892439839960802
# product_name_vectorizer__ravioli: 5.7172727222960695
# product_name_vectorizer__taboule: 5.684642214488226
# product_name_vectorizer__quenelles: 5.61610207885915
# product_name_vectorizer__lentilles: 5.358063870585529
# ingredients_vectorizer__eau: 5.32294453757445
# ingredients_vectorizer__sel: 5.17142552079912
# product_name_vectorizer__salade: 5.087307896789684
# product_name_vectorizer__pizza: 5.048087904337949
# product_name_vectorizer__poelee: 5.02327874515992
# product_name_vectorizer__veloute: 5.003390613613557
# product_name_vectorizer__thon: 4.937567143562011
# product_name_vectorizer__choucroute: 4.862797769599446
# product_name_vectorizer__carottes: 4.814838228482689
# product_name_vectorizer__terre: 4.774629122018413
# product_name_vectorizer__ratatouille: 4.768127008437849
# product_name_vectorizer__gratin: 4.570578687184905
# product_name_vectorizer__cassoulet: 4.528727709491565
#
# en:dairies
# product_name_vectorizer__yaourt: 8.315313140289298
# ingredients_vectorizer__lait: 6.634980207315551
# product_name_vectorizer__mg: 6.015136733328391
# product_name_vectorizer__fromage: 5.798773343108437
# product_name_vectorizer__yaourts: 5.752674588381501
# ingredients_vectorizer__ferments: 5.644251003121046
# product_name_vectorizer__creme: 5.285050208019071
# product_name_vectorizer__ecreme: 5.11366673563871
# ingredients_vectorizer__epaississants: 5.008514084857852
# product_name_vectorizer__cancoillotte: 4.876437943321859
# ingredients_vectorizer__amidon: 4.868614418466928
# ingredients_vectorizer__pasteurise: 4.864950412962713
# product_name_vectorizer__camembert: 4.840120551160975
# product_name_vectorizer__tiramisu: 4.562627594340188
# product_name_vectorizer__activia: 4.4950590683010505
# product_name_vectorizer__mozzarella: 4.356963162906445
# ingredients_vectorizer__presure: 4.286345279121313
# ingredients_vectorizer__vache: 4.227890813707894
# product_name_vectorizer__chevre: 4.181349788238733
# product_name_vectorizer__emmental: 4.138580113377452
#
# en:meats
# product_name_vectorizer__poulet: 7.338556039805548
# ingredients_vectorizer__porc: 6.72660088275373
# product_name_vectorizer__jambon: 6.44708970828574
# product_name_vectorizer__dinde: 5.82427413019284
# ingredients_vectorizer__viande: 5.476565684767787
# product_name_vectorizer__saucisson: 5.463287970554903
# ingredients_vectorizer__poulet: 5.447291240805731
# ingredients_vectorizer__bovine: 5.409427601682985
# product_name_vectorizer__saucisses: 4.5978219959932245
# product_name_vectorizer__boudin: 4.59455131386353
# product_name_vectorizer__chorizo: 4.562653722873814
# product_name_vectorizer__saucisse: 4.463843306667659
# ingredients_vectorizer__epices: 4.415662090891691
# product_name_vectorizer__rillettes: 4.403857303990853
# product_name_vectorizer__porc: 4.374593901354058
# product_name_vectorizer__nuggets: 4.24793571311019
# ingredients_vectorizer__dextrose: 4.142486872087725
# ingredients_vectorizer__marinade: 4.061758718944679
# ingredients_vectorizer__cuisson: 3.850311359677789
# product_name_vectorizer__agneau: 3.7969984087783204
#
# en:desserts
# product_name_vectorizer__sorbet: 9.79618350701863
# product_name_vectorizer__compote: 7.852636813607856
# product_name_vectorizer__pots: 6.927880877307229
# product_name_vectorizer__mousse: 6.655004281565533
# product_name_vectorizer__glace: 6.462931502050761
# product_name_vectorizer__dessert: 6.449707088997914
# product_name_vectorizer__glacee: 5.753961956003279
# ingredients_vectorizer__caroube: 5.541003156686469
# product_name_vectorizer__macarons: 5.42124638431596
# product_name_vectorizer__liegeois: 4.974361511102386
# product_name_vectorizer__riz: 4.974198907594837
# product_name_vectorizer__pomme: 4.934562362595654
# product_name_vectorizer__kouign: 4.665134346079567
# product_name_vectorizer__vanille: 4.647291908136198
# product_name_vectorizer__tiramisu: 4.617215150305864
# product_name_vectorizer__danette: 4.354632798683002
# product_name_vectorizer__semoule: 4.1755777299821455
# product_name_vectorizer__cotta: 4.089017197469207
# ingredients_vectorizer__pommes: 4.065980649343406
# ingredients_vectorizer__poires: 4.030355414642036
#
# en:frozen-foods
# product_name_vectorizer__sorbet: 10.352745923255009
# product_name_vectorizer__glacee: 7.77709589305138
# product_name_vectorizer__surgele: 7.627132660598802
# product_name_vectorizer__glace: 6.721490474484734
# product_name_vectorizer__surgeles: 6.055646275840437
# ingredients_vectorizer__liquide: 6.0171777190416975
# ingredients_vectorizer__caroube: 5.967639248728807
# product_name_vectorizer__surgelees: 5.933989528067635
# product_name_vectorizer__surgelee: 5.682923296086607
# ingredients_vectorizer__mozzarella: 4.517953674342613
# product_name_vectorizer__frites: 4.3505995731530716
# ingredients_vectorizer__glacee: 4.177032543337909
# product_name_vectorizer__crevettes: 4.160000327278669
# product_name_vectorizer__rissolees: 4.077880552919961
# ingredients_vectorizer__rehydrate: 4.008925504350256
# product_name_vectorizer__rondelles: 3.933004294309852
# ingredients_vectorizer__guar: 3.871854489028605
# ingredients_vectorizer__terre: 3.859795942146967
# ingredients_vectorizer__stabilisants: 3.8546009480827874
# ingredients_vectorizer__glace: 3.8403574173615582
#
# en:breakfasts
# product_name_vectorizer__confiture: 13.986731342165248
# product_name_vectorizer__miel: 9.11718650056331
# product_name_vectorizer__muesli: 8.272184990959174
# product_name_vectorizer__tartiner: 7.696741237105567
# ingredients_vectorizer__pectine: 6.412455460851615
# ingredients_vectorizer__gelifiant: 6.219370015416954
# product_name_vectorizer__gelee: 5.801431143836024
# product_name_vectorizer__flocons: 5.331984152746727
# product_name_vectorizer__marmelade: 5.314629144382127
# ingredients_vectorizer__sucre: 5.311421441944091
# product_name_vectorizer__flakes: 5.256752779437641
# ingredients_vectorizer__avoine: 4.677121816842913
# ingredients_vectorizer__pectines: 4.662166527458123
# product_name_vectorizer__nutella: 4.640579954113003
# ingredients_vectorizer__miel: 4.580153030708992
# product_name_vectorizer__pate: 4.392238607051307
# ingredients_vectorizer__flocons: 3.9167451824952515
# product_name_vectorizer__poudre: 3.807219190795787
# ingredients_vectorizer__fer: 3.789401276879474
# product_name_vectorizer__granola: 3.710928688724959
#
# en:cheeses
# product_name_vectorizer__fromage: 7.7672128534245175
# ingredients_vectorizer__pasteurise: 6.142222747373996
# product_name_vectorizer__cancoillotte: 5.981590897970742
# product_name_vectorizer__camembert: 5.973974718854654
# ingredients_vectorizer__presure: 5.899361146634867
# ingredients_vectorizer__vache: 5.114882631307298
# ingredients_vectorizer__fromage: 5.111755729797525
# product_name_vectorizer__mozzarella: 5.045777466241502
# product_name_vectorizer__feta: 4.99247834312412
# product_name_vectorizer__mg: 4.986899595328841
# product_name_vectorizer__emmental: 4.96406590599992
# product_name_vectorizer__comte: 4.962710566677406
# product_name_vectorizer__burrata: 4.895721793586729
# product_name_vectorizer__mascarpone: 4.855558149779366
# ingredients_vectorizer__pasteurises: 4.766293274675751
# product_name_vectorizer__faisselle: 4.726010694095044
# ingredients_vectorizer__cru: 4.644245146247863
# ingredients_vectorizer__sel: 4.49077010411806
# product_name_vectorizer__roquefort: 4.381803445296913
# ingredients_vectorizer__fonte: 4.33127073288232
#
# en:biscuits
# product_name_vectorizer__biscuits: 9.260098099491826
# product_name_vectorizer__cookies: 8.382792253155138
# product_name_vectorizer__sables: 8.111505189923326
# ingredients_vectorizer__farine: 6.901417275782348
# product_name_vectorizer__galettes: 6.823385100090659
# ingredients_vectorizer__ammonium: 6.535530281036762
# product_name_vectorizer__biscuit: 6.032884823616834
# product_name_vectorizer__florentins: 5.35575806036631
# product_name_vectorizer__gaufrettes: 5.196666880052135
# product_name_vectorizer__sable: 4.972842709681411
# product_name_vectorizer__shortbread: 4.802545519154562
# product_name_vectorizer__palmiers: 4.678112421025664
# product_name_vectorizer__petit: 4.585240772655911
# ingredients_vectorizer__beurre: 4.54841109803773
# product_name_vectorizer__cuillers: 4.475511991649939
# product_name_vectorizer__speculoos: 4.41967399411431
# ingredients_vectorizer__lever: 4.399366835667462
# product_name_vectorizer__palets: 4.318114426807788
# product_name_vectorizer__barquettes: 4.212067921934566
# ingredients_vectorizer__palme: 4.169360726122224
#
# en:groceries
# product_name_vectorizer__sauce: 13.323431856311254
# product_name_vectorizer__moutarde: 8.551739985729048
# product_name_vectorizer__coulis: 8.006770138331664
# product_name_vectorizer__tzatziki: 6.741985225096851
# product_name_vectorizer__ketchup: 6.541427941885518
# product_name_vectorizer__bouillon: 6.52170892798622
# product_name_vectorizer__sel: 6.481425857244004
# product_name_vectorizer__mayonnaise: 5.956332661745343
# product_name_vectorizer__poivre: 5.397833601386183
# product_name_vectorizer__pesto: 5.045399964880443
# ingredients_vectorizer__vinaigre: 4.916676557320841
# product_name_vectorizer__oignons: 4.709768634538368
# product_name_vectorizer__vinaigre: 4.6543187454644
# product_name_vectorizer__fond: 4.357248705006674
# product_name_vectorizer__moulu: 4.062806572699005
# product_name_vectorizer__ail: 4.035147389807842
# ingredients_vectorizer__aneth: 3.9598179347052946
# product_name_vectorizer__oignon: 3.865090496127943
# product_name_vectorizer__vinaigrette: 3.8218990581489125
# product_name_vectorizer__piment: 3.7845026336750176
#
# en:fats
# product_name_vectorizer__huile: 12.001321298231485
# product_name_vectorizer__beurre: 9.789060872672353
# ingredients_vectorizer__huile: 6.5757227379229075
# product_name_vectorizer__oil: 5.052350312531394
# ingredients_vectorizer__beurre: 4.687024320207681
# product_name_vectorizer__doux: 4.3435908292495
# ingredients_vectorizer__oil: 4.248746668194252
# product_name_vectorizer__margarine: 4.13767548186729
# product_name_vectorizer__graisse: 4.052872365797842
# product_name_vectorizer__vierge: 3.883334764489878
# product_name_vectorizer__baratte: 3.677751347891233
# product_name_vectorizer__huiles: 3.5689958488343674
# ingredients_vectorizer__huiles: 3.4122012661825183
# product_name_vectorizer__demi: 3.2863713395668386
# product_name_vectorizer__omega: 3.2716326074880255
# product_name_vectorizer__olio: 3.243184333491343
# product_name_vectorizer__tartine: 3.209841036888579
# product_name_vectorizer__butter: 3.1876476028264533
# ingredients_vectorizer__vegetales: 3.057573197368988
# product_name_vectorizer__oliva: 3.0108925690799393
#
# en:chocolates
# ingredients_vectorizer__cacao: 7.538785304877095
# product_name_vectorizer__chocolat: 7.290742196983689
# product_name_vectorizer__noir: 6.8559445208972525
# product_name_vectorizer__cacao: 4.926314894388726
# product_name_vectorizer__chocolate: 4.477979770721611
# product_name_vectorizer__lait: 3.98382687339118
# ingredients_vectorizer__minimum: 3.957355378209441
# product_name_vectorizer__nesquik: 3.9565474302815047
# product_name_vectorizer__dark: 3.8654559089611626
# product_name_vectorizer__tablette: 3.81578856908734
# product_name_vectorizer__paques: 3.765451856683969
# ingredients_vectorizer__beurre: 3.7431457738096707
# ingredients_vectorizer__lecithine: 3.7052055931056507
# product_name_vectorizer__eclats: 3.6126179833623566
# product_name_vectorizer__schokolade: 3.383820440863489
# product_name_vectorizer__calendrier: 3.2647295279133313
# ingredients_vectorizer__speculoos: 3.215550190260514
# product_name_vectorizer__blanc: 3.2020352500937963
# product_name_vectorizer__intense: 2.9775421491472476
# product_name_vectorizer__avent: 2.9263536272950974
#
# en:sauces
# product_name_vectorizer__sauce: 15.52183432594899
# product_name_vectorizer__moutarde: 10.254904495670859
# product_name_vectorizer__coulis: 9.108210563531621
# product_name_vectorizer__ketchup: 7.891028063431785
# product_name_vectorizer__tzatziki: 7.77166316236518
# product_name_vectorizer__mayonnaise: 6.956216472430762
# product_name_vectorizer__pesto: 6.047811671433862
# product_name_vectorizer__vinaigrette: 5.42346999516248
# ingredients_vectorizer__vinaigre: 5.069793344055401
# ingredients_vectorizer__tomates: 4.915406242425059
# product_name_vectorizer__guacamole: 4.317024894423957
# ingredients_vectorizer__lactique: 4.201434549754654
# product_name_vectorizer__bolognaise: 4.070342320091886
# ingredients_vectorizer__pulpe: 3.903518941785904
# product_name_vectorizer__salsa: 3.792748875821149
# product_name_vectorizer__harissa: 3.5386622691303486
# ingredients_vectorizer__xanthane: 3.3346879297069534
# ingredients_vectorizer__piment: 3.242368016951207
# product_name_vectorizer__tomates: 3.1131630211518257
# product_name_vectorizer__sugo: 3.0622814932805893

# %%
no_cat_df = fr_df[pd.isnull(fr_df['categories_tags']) & pd.notnull(fr_df['ingredients_text'])]

# %%
y_pred = classifier.predict_proba(no_cat_df)

# %%
y_pred_cat = []
y_pred_prob = []

for i in range(y_pred.shape[0]):
    row = y_pred[i]
    indexes = (row > 0.5).nonzero()[0]
    
    if len(indexes):
        row_cat = selected_categories[row.argmax()]
        y_pred_cat.append(row_cat)
        y_pred_prob.append(row.max())
    else:
        y_pred_cat.append(np.NaN)
        y_pred_prob.append(np.NaN)

# %%
no_cat_df['predicted_categories_tag'] = y_pred_cat
no_cat_df['predicted_categories_prob'] = y_pred_prob
# Out:
# /usr/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /usr/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
no_cat_df
# Out:
#                   code                                                url  \
# 0        0000000000017  http://world-en.openfoodfacts.org/product/0000...
# 1        0000000000031  http://world-en.openfoodfacts.org/product/0000...
# 2        0000000000123  http://world-en.openfoodfacts.org/product/0000...
# 3        0000000000291  http://world-en.openfoodfacts.org/product/0000...
# 4        0000000000949  http://world-en.openfoodfacts.org/product/0000...
# 5        0000000000970  http://world-en.openfoodfacts.org/product/0000...
# 6        0000000001001  http://world-en.openfoodfacts.org/product/0000...
# 7        0000000001007  http://world-en.openfoodfacts.org/product/0000...
# 8        0000000001137  http://world-en.openfoodfacts.org/product/0000...
# 9        0000000001151  http://world-en.openfoodfacts.org/product/0000...
# 10       0000000001199  http://world-en.openfoodfacts.org/product/0000...
# 12       0000000001311  http://world-en.openfoodfacts.org/product/0000...
# 13       0000000001328  http://world-en.openfoodfacts.org/product/0000...
# 14       0000000001564  http://world-en.openfoodfacts.org/product/0000...
# 15       0000000001663  http://world-en.openfoodfacts.org/product/0000...
# 16       0000000001670  http://world-en.openfoodfacts.org/product/0000...
# 18       0000000002042  http://world-en.openfoodfacts.org/product/0000...
# 19       0000000002103  http://world-en.openfoodfacts.org/product/0000...
# 20       0000000002219  http://world-en.openfoodfacts.org/product/0000...
# 21       0000000002257  http://world-en.openfoodfacts.org/product/0000...
# 22       0000000002264  http://world-en.openfoodfacts.org/product/0000...
# 23       0000000002363  http://world-en.openfoodfacts.org/product/0000...
# 24       0000000002400  http://world-en.openfoodfacts.org/product/0000...
# 25       0000000002417  http://world-en.openfoodfacts.org/product/0000...
# 26       0000000003018  http://world-en.openfoodfacts.org/product/0000...
# 27       0000000003087  http://world-en.openfoodfacts.org/product/0000...
# 28       0000000003384  http://world-en.openfoodfacts.org/product/0000...
# 29       0000000003780  http://world-en.openfoodfacts.org/product/0000...
# 30       0000000003803  http://world-en.openfoodfacts.org/product/0000...
# 31       0000000003827  http://world-en.openfoodfacts.org/product/0000...
# ...                ...                                                ...
# 676446        99515874  http://world-en.openfoodfacts.org/product/9951...
# 676447        99534592  http://world-en.openfoodfacts.org/product/9953...
# 676451        99619558  http://world-en.openfoodfacts.org/product/9961...
# 676452        99663339  http://world-en.openfoodfacts.org/product/9966...
# 676453        99695743  http://world-en.openfoodfacts.org/product/9969...
# 676455       997326239  http://world-en.openfoodfacts.org/product/9973...
# 676456   9974363992573  http://world-en.openfoodfacts.org/product/9974...
# 676457  99751013590360  http://world-en.openfoodfacts.org/product/9975...
# 676458   9977842330026  http://world-en.openfoodfacts.org/product/9977...
# 676460   9985023697844  http://world-en.openfoodfacts.org/product/9985...
# 676461   9985043117995  http://world-en.openfoodfacts.org/product/9985...
# 676462   9990000024742  http://world-en.openfoodfacts.org/product/9990...
# 676463   9990000039692  http://world-en.openfoodfacts.org/product/9990...
# 676464        99903336  http://world-en.openfoodfacts.org/product/9990...
# 676466   9991111114117  http://world-en.openfoodfacts.org/product/9991...
# 676467   9991111116111  http://world-en.openfoodfacts.org/product/9991...
# 676468   9996015650648  http://world-en.openfoodfacts.org/product/9996...
# 676470   9998070000000  http://world-en.openfoodfacts.org/product/9998...
# 676471   9999001900031  http://world-en.openfoodfacts.org/product/9999...
# 676473   9999200847366  http://world-en.openfoodfacts.org/product/9999...
# 676474        99993306  http://world-en.openfoodfacts.org/product/9999...
# 676475        99996666  http://world-en.openfoodfacts.org/product/9999...
# 676478   9999900401301  http://world-en.openfoodfacts.org/product/9999...
# 676479   9999990009678  http://world-en.openfoodfacts.org/product/9999...
# 676480   9999990060631  http://world-en.openfoodfacts.org/product/9999...
# 676481   9999991042704  http://world-en.openfoodfacts.org/product/9999...
# 676482   9999991042728  http://world-en.openfoodfacts.org/product/9999...
# 676483   9999991042742  http://world-en.openfoodfacts.org/product/9999...
# 676484   9999991149090  http://world-en.openfoodfacts.org/product/9999...
# 676485        99999995  http://world-en.openfoodfacts.org/product/9999...
#
#        last_modified_t                                      product_name  \
# 0           1529059204                                  Vitória crackers
# 1           1539464817                                             Cacao
# 2           1535737986                             Sauce Sweety chili 0%
# 3           1534239732                                         Mendiants
# 4           1523440823                         Salade de carottes râpées
# 5           1520506371                       Fromage blanc aux myrtilles
# 6           1537766416
# 7           1538127565                                          Vainilla
# 8           1539781578                                 Baguette parisien
# 9           1537883538                     &quot;Baguette Lyonnais&quot;
# 10          1517833609                            Solène céréales poulet
# 12          1520419813                        Salade de fruits exotiques
# 13          1532982384                                  Chouquettes x 30
# 14          1523443872                               Fromage blanc pêche
# 15          1509478053                            Crème dessert chocolat
# 16          1540478386                              Bouillie de sarrasin
# 18          1523528261                                  Paëlla de poulet
# 19          1539629527                            Aiguillettes de poulet
# 20          1522840950                                Salade shaker chef
# 21          1520506124                    Salade de macedoine de légumes
# 22          1518439971                                 Baguette Poitevin
# 23          1539603411                                      Suedois thon
# 24          1520248080                                   Ciabatta Bombay
# 25          1521725617                                     Ciabatta Roma
# 26          1538739049                                     Salade tomate
# 27          1474103893                                Farine de blé noir
# 28          1520597247                           Mousse chocolat douceur
# 29          1528624345                                 Coca des flandres
# 30          1526818062                                  Brochettes dinde
# 31          1518691490                                    Suedois saumon
# ...                ...                                               ...
# 676446      1513519093                                      Mini stollen
# 676447      1515761789                                Saumon à l'oseille
# 676451      1531136252                           Triple chocolaté crunch
# 676452      1528628959                          Côtés d agneau à griller
# 676453      1540531171                       Soupe minestrone avec bacon
# 676455      1536927061                                         Maroilles
# 676456      1540412338                     Toasted muesli almond & pecan
# 676457      1538199244
# 676458      1536834434                      Limonade Japonnaise Gazeuses
# 676460      1531056620                                 Barquettes Fraise
# 676461      1534931796  Pâte à tartiner aux noisettes et au cacao maigre
# 676462      1538245441                              Pur cacao biologique
# 676463      1537272563                                 Rooïbos aromatise
# 676464      1530961845                                   Jus multifruits
# 676466      1522496111                                  Nectar d'abricot
# 676467      1527245196                          Puree de pomme framboise
# 676468      1523963734                          Quick milk magic slipper
# 676470      1538808669                                    Miel de fleurs
# 676471      1537440915                                          Formula1
# 676473      1514221238                                      Choco pearls
# 676474      1521230354                       Pizza thon cuite sur pierre
# 676475      1534611776          Class A'peel Dot Sparkler Stickers-black
# 676478      1515171193                                           Kabanos
# 676479      1535046964                          Vinaigre seve de bouleau
# 676480      1537878117                              Cailloux aux amandes
# 676481      1525862792                                    Yaourt vanille
# 676482      1531913884                              Yaourt mûre myrtille
# 676483      1539597360                           Mousse au chocolat noir
# 676484      1519157737                                       Riz parfumé
# 676485      1538818435                             Steak haché pur boeuf
#
#        generic_name              brands_tags categories_tags countries_tags  \
# 0               NaN                      NaN             NaN      en:france
# 1               NaN                      NaN             NaN      en:france
# 2               NaN                      NaN             NaN      en:france
# 3               NaN                      NaN             NaN      en:france
# 4               NaN                      NaN             NaN      en:france
# 5               NaN                      NaN             NaN      en:france
# 6               NaN                      NaN             NaN      en:france
# 7               NaN                      NaN             NaN      en:france
# 8               NaN                      NaN             NaN      en:france
# 9               NaN                      NaN             NaN      en:france
# 10              NaN                    crous             NaN      en:france
# 12              NaN                      NaN             NaN      en:france
# 13              NaN                      NaN             NaN      en:france
# 14              NaN                      NaN             NaN      en:france
# 15              NaN  ferme-de-la-fremondiere             NaN      en:france
# 16              NaN                      NaN             NaN      en:france
# 18              NaN                      NaN             NaN      en:france
# 19              NaN                      NaN             NaN      en:france
# 20              NaN                      NaN             NaN      en:france
# 21              NaN                      NaN             NaN      en:france
# 22              NaN              crous-resto             NaN      en:france
# 23              NaN                      NaN             NaN      en:france
# 24              NaN                      NaN             NaN      en:france
# 25              NaN                      NaN             NaN      en:france
# 26              NaN                      NaN             NaN      en:france
# 27              NaN          ferme-t-y-r-nao             NaN      en:france
# 28              NaN                      NaN             NaN      en:france
# 29              NaN                      NaN             NaN      en:france
# 30              NaN                      NaN             NaN      en:france
# 31              NaN                    crous             NaN      en:france
# ...             ...                      ...             ...            ...
# 676446          NaN                 favorina             NaN      en:france
# 676447          NaN            toque-du-chef             NaN      en:france
# 676451          NaN                      NaN             NaN      en:france
# 676452          NaN                      NaN             NaN      en:france
# 676453          NaN                      NaN             NaN      en:france
# 676455          NaN                  fauquet             NaN      en:france
# 676456          NaN                      NaN             NaN      en:france
# 676457          NaN                      NaN             NaN      en:france
# 676458          NaN                      NaN             NaN      en:france
# 676460          NaN                      NaN             NaN      en:france
# 676461          NaN                      NaN             NaN      en:france
# 676462          NaN                      NaN             NaN      en:france
# 676463          NaN        comptoirs-richard             NaN      en:france
# 676464          NaN                      NaN             NaN      en:france
# 676466          NaN                      NaN             NaN      en:france
# 676467          NaN                      NaN             NaN      en:france
# 676468          NaN                      NaN             NaN      en:france
# 676470          NaN                      NaN             NaN      en:france
# 676471          NaN                      NaN             NaN      en:france
# 676473          NaN                     cara             NaN      en:france
# 676474          NaN                      NaN             NaN      en:france
# 676475          NaN                      NaN             NaN      en:france
# 676478          NaN               tarczynski             NaN      en:france
# 676479          NaN                      NaN             NaN      en:france
# 676480          NaN                      NaN             NaN      en:france
# 676481          NaN                      NaN             NaN      en:france
# 676482          NaN                      NaN             NaN      en:france
# 676483          NaN                      NaN             NaN      en:france
# 676484          NaN            king-elephant             NaN      en:france
# 676485          NaN                      NaN             NaN      en:france
#
#                                          ingredients_text main_category_en  \
# 0                                                                      NaN
# 1                                                                      NaN
# 2                                                                      NaN
# 3                                                                      NaN
# 4                                                                      NaN
# 5                                                                      NaN
# 6                                                                      NaN
# 7                                                                      NaN
# 8                                                                      NaN
# 9                                                                      NaN
# 10      antioxydant : ébahorbate de sodium, 00 orant •...              NaN
# 12                                                                     NaN
# 13                                                                     NaN
# 14                                                                     NaN
# 15      Lait entier, sucre, amidon de maïs, cacao, Aga...              NaN
# 16                                                                     NaN
# 18                                                                     NaN
# 19                                                                     NaN
# 20                                                                     NaN
# 21                                                                     NaN
# 22      baguette Poite vin Pain baguette 50,6%: fqrine...              NaN
# 23                                                                     NaN
# 24                                                                     NaN
# 25                                                                     NaN
# 26                                                                     NaN
# 27                                                                     NaN
# 28                                                                     NaN
# 29                                                                     NaN
# 30                                                                     NaN
# 31      Paln suédois 42,6%: farine de BLÉ, eau, farine...              NaN
# ...                                                   ...              ...
# 676446  45 % massepain (44% amandes, sucre, sirop de g...              NaN
# 676447  '1/1/1/ Riz basmati accompagné d'une sauce à l...              NaN
# 676451                                                                 NaN
# 676452                                                                 NaN
# 676453                                                                 NaN
# 676455                                                                 NaN
# 676456                                                                 NaN
# 676457                                                                 NaN
# 676458                                                                 NaN
# 676460                                                                 NaN
# 676461                                                                 NaN
# 676462                                                                 NaN
# 676463                                                                 NaN
# 676464                                                                 NaN
# 676466                                                                 NaN
# 676467                                                                 NaN
# 676468                                                                 NaN
# 676470                                                                 NaN
# 676471                                                                 NaN
# 676473  sucre,beurre de cacao,poudre de jait.entier,fa...              NaN
# 676474                                                                 NaN
# 676475                                                                 NaN
# 676478  KABANOSÈRÇ Sktadn' wiep -zEkrobia, Guszcz 'o.e...              NaN
# 676479                                                                 NaN
# 676480                                                                 NaN
# 676481                                                                 NaN
# 676482                                                                 NaN
# 676483                                                                 NaN
# 676484                                                                 NaN
# 676485                                                                 NaN
#
#        predicted_categories_tag  predicted_categories_prob
# 0                           NaN                        NaN
# 1              en:sugary-snacks                   0.878868
# 2                  en:groceries                   0.835508
# 3                           NaN                        NaN
# 4                      en:meals                   0.991342
# 5                    en:cheeses                   0.679874
# 6                           NaN                        NaN
# 7                           NaN                        NaN
# 8                           NaN                        NaN
# 9                           NaN                        NaN
# 10                          NaN                        NaN
# 12                          NaN                        NaN
# 13                          NaN                        NaN
# 14                   en:cheeses                   0.846457
# 15                   en:dairies                   0.946049
# 16                          NaN                        NaN
# 18                     en:meals                   0.558525
# 19                     en:meats                   0.956335
# 20                          NaN                        NaN
# 21                     en:meals                   0.705579
# 22                          NaN                        NaN
# 23                     en:meals                   0.804631
# 24                          NaN                        NaN
# 25                          NaN                        NaN
# 26                     en:meals                   0.501759
# 27                          NaN                        NaN
# 28                  en:desserts                   0.802974
# 29                 en:beverages                   0.654128
# 30                     en:meats                   0.652098
# 31             en:sugary-snacks                   0.690243
# ...                         ...                        ...
# 676446         en:sugary-snacks                   0.968003
# 676447                 en:meals                   0.935221
# 676451                      NaN                        NaN
# 676452                 en:meats                   0.651605
# 676453                 en:meals                   0.538311
# 676455                      NaN                        NaN
# 676456            en:breakfasts                   0.735159
# 676457                      NaN                        NaN
# 676458             en:beverages                   0.975261
# 676460                      NaN                        NaN
# 676461            en:breakfasts                   0.943010
# 676462         en:sugary-snacks                   0.696410
# 676463             en:beverages                   0.805651
# 676464             en:beverages                   0.999238
# 676466             en:beverages                   0.979985
# 676467              en:desserts                   0.723050
# 676468                      NaN                        NaN
# 676470            en:breakfasts                   0.986183
# 676471                      NaN                        NaN
# 676473         en:sugary-snacks                   0.976325
# 676474                 en:meals                   0.782772
# 676475                      NaN                        NaN
# 676478                      NaN                        NaN
# 676479                      NaN                        NaN
# 676480         en:sugary-snacks                   0.744748
# 676481               en:dairies                   0.986038
# 676482               en:dairies                   0.783341
# 676483              en:desserts                   0.794259
# 676484             en:beverages                   0.504924
# 676485                 en:meats                   0.903072
#
# [282234 rows x 12 columns]

# %%
export_df = no_cat_df.drop(['url', 'generic_name', 'brands_tags', 'categories_tags', 'countries_tags', 'product_name', 'ingredients_text', 'main_category_en'], axis=1)
export_df = export_df[pd.notnull(export_df.predicted_categories_tag)]
export_df.to_json('predicted_categories.json', orient='records', lines=True)
